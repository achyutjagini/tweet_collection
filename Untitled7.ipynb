# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd


query="bitcoin until:2022-05-01 since:2022-04-20"

#query = "until:2022-11-30 since:2022-11-20"
tweets = []
limit =100


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.user.username, tweet.user.followersCount,tweet.user.location, tweet.user.description,tweet.replyCount,
    tweet.retweetCount,tweet.user.verified,tweet.date,tweet.content])

columns = ['user_name','user_followers','user_location','user_description','tweet_replies','tweet_retweets','user_verified','date','text']

df = pd.DataFrame(tweets, columns=columns)

print(df)


#columns = ['user_name','user_location','user_description','user_created','user_followers','user_friends','user_favourites','user_verified','date','text','source','is_retweet']

#data = []
#for tweet in tqdm(tweets):
 #   data.append([tweet.user.name, tweet.user.location, tweet.user.description,tweet.user.created_at,tweet.user.followers_count,
  #  tweet.user.friends_count,tweet.user.favourites_count,tweet.user.verified,tweet.created_at,tweet.full_text,tweet.source,tweet.retweeted])



# to save to csv
df.to_csv('tweets_new_old_range.csv')
# Out:
#           user_name  user_followers  user_location  \
# 0     CommonVeggies             177           Soil
# 1       MarkQuarter             658
# 2       SimpleC9000              10
# 3        Vedant2103             252         🇾⍥ÜṘ ❤
# 4           458Aman              19
# ..              ...             ...            ...
# 95      Bitcoin_is_             991  Pale Blue Dot
# 96  CrossCountryRAP            3075            USA
# 97  esrarengizcizgi             136
# 98     keet03crypto              23
# 99    alsubaiei2021            5309    دولة الكويت
#
#                                      user_description  tweet_replies  \
# 0                      Carrot, lettuce, cabbage, etc.              1
# 1                      Quarterly market news coverage              0
# 2                                                                  0
# 3   Sweet dreams are made of this\nWho am I to dis...              0
# 4   Social worker,  TRSian forever.... Jai Telanga...              4
# ..                                                ...            ...
# 95  🔥 Why isn’t your space heater securing the pro...              0
# 96  Artist Management, Music Production & Distribu...              0
# 97  Burada yer alan hiçbir bilgi yatırım tavsiyesi...              0
# 98  #Xrp holder, husband, father, do your own rese...              0
# 99                        فشلت كثيرًا . ولكن لن أتوقف              0
#
#     tweet_retweets  user_verified                      date  \
# 0                0          False 2022-04-30 23:59:59+00:00
# 1                1          False 2022-04-30 23:59:57+00:00
# 2                0          False 2022-04-30 23:59:55+00:00
# 3                0          False 2022-04-30 23:59:53+00:00
# 4                0          False 2022-04-30 23:59:52+00:00
# ..             ...            ...                       ...
# 95               0          False 2022-04-30 23:57:20+00:00
# 96               0          False 2022-04-30 23:57:19+00:00
# 97               0          False 2022-04-30 23:57:18+00:00
# 98               0          False 2022-04-30 23:57:17+00:00
# 99               0          False 2022-04-30 23:57:17+00:00
#
#                                                  text
# 0   @Quinnvestments would love to engage more with...
# 1   @wlwatts What are actually "stupid" &amp; "evi...
# 2   SimpleC found #bitcoin in a Blue vault at this...
# 3                @Minecraft #Bitcoin  Genesis Block !
# 4                               @Bitcoin #cats coming
# ..                                                ...
# 95  @pmarca You think even his stoicism could make...
# 96  The sixth installment of my trade journal feat...
# 97  #mana\n\nManausdt  11 Nisan tarihli analizim v...
# 98  @NCashOfficial At the rate we’re dipping.And B...
# 99  #dent حصل ولا ماحصل 😎\n\n#البتكوين #عملات_رقمي...
#
# [100 rows x 9 columns]
