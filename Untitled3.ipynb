# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd


query="bitcoin until:2022-11-30 since:2022-11-20"

#query = "until:2022-11-30 since:2022-11-20"
tweets = []
limit =100000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.user.username, tweet.user.followersCount,tweet.user.location, tweet.user.description,tweet.replyCount,
    tweet.retweetCount,tweet.user.verified,tweet.date,tweet.content])

columns = ['user_name','user_followers','user_location','user_description','tweet_replies','tweet_retweets','user_verified','date','text']

df = pd.DataFrame(tweets, columns=columns)

print(df)


#columns = ['user_name','user_location','user_description','user_created','user_followers','user_friends','user_favourites','user_verified','date','text','source','is_retweet']

#data = []
#for tweet in tqdm(tweets):
 #   data.append([tweet.user.name, tweet.user.location, tweet.user.description,tweet.user.created_at,tweet.user.followers_count,
  #  tweet.user.friends_count,tweet.user.favourites_count,tweet.user.verified,tweet.created_at,tweet.full_text,tweet.source,tweet.retweeted])



# to save to csv
df.to_csv('tweets_new_2.csv')
# Out:
#              user_name  user_followers                   user_location  \
# 0      CryptoBlckParty            3550  100% Not the USA, Metaplex ;-)
# 1          BTCHabercom           60248                         Türkiye
# 2         EdCash_Token              22               São Paulo, Brasil
# 3           Macronaut_            2303                        Mesa, AZ
# 4       _morphilibrium             122                              UK
# ...                ...             ...                             ...
# 99995   cryptovince___            6788
# 99996        ScammoonR             459
# 99997  crypto_whispers            4708
# 99998      FWeissbarth             937
# 99999    IAmBitcoinBot            1851                          server
#
#                                         user_description  tweet_replies  \
# 0      Building Back Together\nUse Hardware Wallet VP...              0
# 1      BTCHaber; blokzincirin ve kripto paraların, ge...              0
# 2      #EdCash (EDCS) is an #Educational #Token to be...              0
# 3      #bitcoin dad humor: Where does The Fed store t...              0
# 4      Entrepreneur, investor, pro gambler and bullsh...              0
# ...                                                  ...            ...
# 99995  ⚡️#Bitcoin + #Crypto◀️Trader 📊/Investor📈/Finan...              4
# 99996                 Shilling the truth to the cultists              1
# 99997  Latest #crypto news and market prices.\nNone o...              0
# 99998                                                                 0
# 99999     I Tweet the latest #Bitcoin price every 5 min.              2
#
#        tweet_retweets  user_verified                      date  \
# 0                   0          False 2022-11-29 23:59:56+00:00
# 1                   0          False 2022-11-29 23:59:53+00:00
# 2                   1          False 2022-11-29 23:59:48+00:00
# 3                   1          False 2022-11-29 23:59:45+00:00
# 4                   0          False 2022-11-29 23:59:45+00:00
# ...               ...            ...                       ...
# 99995               0          False 2022-11-28 12:38:19+00:00
# 99996               0          False 2022-11-28 12:38:17+00:00
# 99997               0          False 2022-11-28 12:38:16+00:00
# 99998               0          False 2022-11-28 12:38:16+00:00
# 99999               0          False 2022-11-28 12:38:10+00:00
#
#                                                     text
# 0      @ChartFuMonkey @phantom @ethereum @0xPolygon @...
# 1      Miami belediye başkanı Francis Suarez, bir yıl...
# 2      Historic! 🇧🇷 Brazil approves law on #Bitcoin a...
# 3      @jimcramer #bitcoin going up!!! Yey thank you ...
# 4      Hodling bitcoin is hard at times like now beca...
# ...                                                  ...
# 99995  If you think #Bitcoin  $BTC and #Crypto is dea...
# 99996  @logicalgraphs @TeamKujira ANYTHING other than...
# 99997  Salvadoran Group Files Lawsuits Against Presid...
# 99998              #BTC #Bitcoin https://t.co/4zOo8VYKLQ
# 99999      Current #Bitcoin Price is $16233 #BTC #Crypto
#
# [100000 rows x 9 columns]
